# %% [markdown]
# # EDA Project

# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Telco-Customer-Churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.TotalCharges = df.tenure * df.MonthlyCharges
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
cat_columns = [feature for feature in df.columns if df[feature].dtype == 'str' or df[feature].dtype ==  'O']
num_columns =  [feature for feature in df.columns if df[feature].dtype == 'int' or df[feature].dtype =='float']
df[num_columns]
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 0                 0       1           29.85         29.85
# 1                 0      34           56.95       1936.30
# 2                 0       2           53.85        107.70
# 3                 0      45           42.30       1903.50
# 4                 0       2           70.70        141.40
# ...             ...     ...             ...           ...
# 7038              0      24           84.80       2035.20
# 7039              0      72          103.20       7430.40
# 7040              0      11           29.60        325.60
# 7041              1       4           74.40        297.60
# 7042              0      66          105.65       6972.90
#
# [7043 rows x 4 columns]

# %% [markdown]
# ### Maximum peoples left the service in 18 months so we have to give them special offers till first 18 months

# %%
df.groupby('Churn')['tenure'].mean()
# Out:
# Churn
# No     37.569965
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack')
plt.title('Tenure Distribution by Churn')
plt.show()
# maximmum peoples left the service in first month

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='MonthlyCharges', hue='Churn', multiple='stack')
plt.title('Monthly Charges by Churn')
plt.show()

# %% [markdown]
# ### In the range of 70-110 when charges increases the churn rate is high so maybe company not giving best services in premium plans

# %%
sns.countplot(x='InternetService', hue='Churn', data=df)
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %% [markdown]
# ### Maximum churn rate is of Fibre Optics Service Customers

# %%
sns.countplot(x='InternetService', hue='TechSupport', data=df[df['Churn']=='Yes'])
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %% [markdown]
# ### Maximum peoples left of fibre optics due to lack of tech support
# ### Maybe Competitor giving same service in less price

# %%
sns.countplot(x='SeniorCitizen', hue='Churn', data=df)
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %%
df = df.replace({'Male':1, 'Female':0,'Yes':1,'No':0, 'No internet service':2, 'No phone service':2})
df
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG      0              0       1          0       1
# 1     5575-GNVDE      1              0       0          0      34
# 2     3668-QPYBK      1              0       0          0       2
# 3     7795-CFOCW      1              0       0          0      45
# 4     9237-HQITU      0              0       0          0       2
# ...          ...    ...            ...     ...        ...     ...
# 7038  6840-RESVB      1              0       1          1      24
# 7039  2234-XADUH      0              0       1          1      72
# 7040  4801-JZAZL      0              0       1          1      11
# 7041  8361-LTMKD      1              1       1          0       4
# 7042  3186-AJIEK      1              0       0          0      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0               0             2             DSL              0  ...
# ...

# %%
for col in df.columns:
    print(f'{col} = {df[col].unique()}')
# Out:
# customerID = <StringArray>
# ['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', '7795-CFOCW', '9237-HQITU',
#  '9305-CDSKC', '1452-KIOVK', '6713-OKOMC', '7892-POOKP', '6388-TABGU',
#  ...
#  '9767-FFLEM', '0639-TSIQW', '8456-QDAVC', '7750-EYXWZ', '2569-WGERO',
#  '6840-RESVB', '2234-XADUH', '4801-JZAZL', '8361-LTMKD', '3186-AJIEK']
# Length: 7043, dtype: str
# gender = [0 1]
# SeniorCitizen = [0 1]
# Partner = [1 0]
# Dependents = [0 1]
# tenure = [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# PhoneService = [0 1]
# MultipleLines = [2 0 1]
# InternetService = ['DSL' 'Fiber optic' 0]
# OnlineSecurity = [0 1 2]
# OnlineBackup = [1 0 2]
# DeviceProtection = [0 1 2]
# TechSupport = [0 1 2]
# StreamingTV = [0 1 2]
# StreamingMovies = [0 1 2]
# Contract = <StringArray>
# ['Month-to-month', 'One year', 'Two year']
# ...

# %%
df[['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','MonthlyCharges','TotalCharges','Churn']] = df[['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','MonthlyCharges','TotalCharges','Churn']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   object
# ...

# %%
cat_col = [feature for feature in df.columns if df[feature].dtype=='O' or df[feature].dtype=='str']
num_col = [feature for feature in df.columns if df[feature].dtype=='int' or df[feature].dtype=='float']
df[num_col]
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  \
# ...

# %%
plt.figure(figsize = (13,10))
corr = df[num_col].corr()
sns.heatmap(data = corr, vmin = -1, vmax = 1, annot = True)
# Out:
# <Axes: >

# %%
x = df[num_col].drop(columns = ['TotalCharges', 'MonthlyCharges','Churn'])
y = df['Churn']

# %%
import sys
# !{sys.executable} -m pip install scikit-learn

# %% [markdown]
# ### Create Model Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x_train,x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 42) 

model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

from sklearn.metrics import confusion_matrix, accuracy_score,  classification_report

# %%
print('confusion matrix\n', confusion_matrix(y_test, y_pred))
print('accuracy_score\n', accuracy_score(y_test, y_pred))
print('classification_report\n', classification_report(y_test, y_pred))
# Out:
# confusion matrix
#  [[1388  151]
#  [ 282  292]]
# accuracy_score
#  0.7950780880265026
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87      1539
#            1       0.66      0.51      0.57       574
#
#     accuracy                           0.80      2113
#    macro avg       0.75      0.71      0.72      2113
# weighted avg       0.78      0.80      0.79      2113

# %% [markdown]
# ### FP or Recall is very high so we use HyperTuning

# %%
from sklearn.model_selection import GridSearchCV
lr_model = LogisticRegression(max_iter=1000)
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'penalty': ['l1', 'l2'],'solver': ['liblinear']}
grid_search = GridSearchCV(estimator=lr_model, param_grid=param_grid, cv=5, scoring='f1')
grid_search.fit(x_train, y_train)
print("Best Parameters:", grid_search.best_params_)
print("Best F1 Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# Best F1 Score: 0.548309529511866

# %% [markdown]
# ### After Applying grid search cv again training model and predicting best value

# %%
best_lr = grid_search.best_estimator_
y_pred_new = best_lr.predict(x_test)

from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, y_pred_new))
print(classification_report(y_test, y_pred_new))
# Out:
# [[1385  154]
#  [ 275  299]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87      1539
#            1       0.66      0.52      0.58       574
#
#     accuracy                           0.80      2113
#    macro avg       0.75      0.71      0.72      2113
# weighted avg       0.79      0.80      0.79      2113

# %% [markdown]
# ### After applying hypertuning not has big change so we need to predict new threshold point and then again predict matrix

# %%
y_probs = best_lr.predict_proba(x_test)[:, 1]
new_threshold = 0.35
y_pred_new = (y_probs >= new_threshold).astype(int)
from sklearn.metrics import classification_report, confusion_matrix
print("--- Results with 0.35 Threshold ---")
print(confusion_matrix(y_test, y_pred_new))
print(classification_report(y_test, y_pred_new))
# Out:
# --- Results with 0.35 Threshold ---
# [[1224  315]
#  [ 180  394]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83      1539
#            1       0.56      0.69      0.61       574
#
#     accuracy                           0.77      2113
#    macro avg       0.71      0.74      0.72      2113
# weighted avg       0.79      0.77      0.77      2113

# %% [markdown]
# ### Predicting which column our model give more value for prediction

# %%
feature_importance = pd.DataFrame({'Feature': x.columns,'Importance': best_lr.coef_[0]})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importance, palette='RdYlGn_r')
plt.title('Feature Importance: What drives Customer Churn?')
plt.xlabel('Coefficient Value (Impact)')
plt.ylabel('Features')
plt.axvline(x=0, color='black', linestyle='--')
plt.show()

# %% [markdown]
# ### Top 3 Features Increases maximum churn rate and Top 3 are Viceversa
